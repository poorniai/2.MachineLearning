# %%
import pickle
filename="Ass_finalized_model_random_forest.sav"

# %%
loaded_model=pickle.load(open(filename,'rb'))
result=loaded_model.predict([[21,25.8,0,0,0]])
result
# Out:
# C:\Users\Poorni Gnaneswaran\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([2085.836938])
