# %%
import pickle

# %%
filename="finalized_model_Mul_Linear.sav";
loaded_model=pickle.load(open(filename,'rb'))
result=loaded_model.predict([[1234,345,4565,1,0]])
result
# Out:
# C:\Users\Poorni Gnaneswaran\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[43994.79745873]])
