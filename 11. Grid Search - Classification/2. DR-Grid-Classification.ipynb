# %%
import numpy as np
import matplotlib as plt
import pandas as pd

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")
dataset.drop("User ID", axis=1)
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset['Purchased'].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
independent = dataset[['Age', 'EstimatedSalary', 'Gender_Male']]
dependent = dataset[['Purchased']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

param_grid = {
    'criterion':['gini', 'entropy', 'log_loss'],
     'max_features':[None,'sqrt','log2'],
    'splitter': ['best','random']
}
grid=GridSearchCV(DecisionTreeClassifier(),param_grid, refit=True, verbose=3, n_jobs=-1,cv=5,scoring='f1_weighted')
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='f1_weighted', verbose=3)

# %%
re= grid.cv_results_
grid_predictions = grid.predict(X_test)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,grid_predictions)

from sklearn.metrics import classification_report
clf_report = classification_report (y_test,grid_predictions)


print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.90      0.92        79
#            1       0.82      0.90      0.86        41
#
#     accuracy                           0.90       120
#    macro avg       0.88      0.90      0.89       120
# weighted avg       0.90      0.90      0.90       120

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.011968      0.002449         0.023748        0.003768
# 1        0.012400      0.002928         0.025494        0.006613
# 2        0.012288      0.001984         0.027412        0.004060
# 3        0.010092      0.003005         0.024644        0.004609
# 4        0.013193      0.002752         0.028283        0.004277
# 5        0.010280      0.001605         0.027011        0.003716
# 6        0.012817      0.003897         0.028040        0.002858
# 7        0.010555      0.000670         0.022354        0.002779
# 8        0.013937      0.000801         0.026933        0.004108
# 9        0.013095      0.003938         0.028587        0.005889
# 10       0.012780      0.002177         0.025892        0.001761
# 11       0.011377      0.003294         0.028273        0.005568
# 12       0.012644      0.002589         0.025685        0.002301
# 13       0.009748      0.001365         0.024612        0.001687
# 14       0.010487      0.001901         0.023468        0.002518
# 15       0.009465      0.001530         0.024669        0.000951
# 16       0.009484      0.001603         0.027022        0.001738
# 17       0.009284      0.002727         0.020857        0.003575
#
#    param_criterion param_max_features param_splitter  \
# 0             gini               None           best
# 1             gini               None         random
# 2             gini               sqrt           best
# 3             gini               sqrt         random
# 4             gini               log2           best
# 5             gini               log2         random
# 6          entropy               None           best
# 7          entropy               None         random
# 8          entropy               sqrt           best
# 9          entropy               sqrt         random
# 10         entropy               log2           best
# 11         entropy               log2         random
# 12        log_loss               None           best
# 13        log_loss               None         random
# 14        log_loss               sqrt           best
# 15        log_loss               sqrt         random
# 16        log_loss               log2           best
# 17        log_loss               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'gini', 'max_features': None, 's...           0.795918
# 1   {'criterion': 'gini', 'max_features': None, 's...           0.816207
# 2   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.795918
# 3   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.791441
# 4   {'criterion': 'gini', 'max_features': 'log2', ...           0.819142
# 5   {'criterion': 'gini', 'max_features': 'log2', ...           0.835985
# 6   {'criterion': 'entropy', 'max_features': None,...           0.819142
# 7   {'criterion': 'entropy', 'max_features': None,...           0.872432
# 8   {'criterion': 'entropy', 'max_features': 'sqrt...           0.855314
# 9   {'criterion': 'entropy', 'max_features': 'sqrt...           0.857143
# 10  {'criterion': 'entropy', 'max_features': 'log2...           0.857143
# 11  {'criterion': 'entropy', 'max_features': 'log2...           0.908880
# 12  {'criterion': 'log_loss', 'max_features': None...           0.819142
# 13  {'criterion': 'log_loss', 'max_features': None...           0.874254
# 14  {'criterion': 'log_loss', 'max_features': 'sqr...           0.855314
# 15  {'criterion': 'log_loss', 'max_features': 'sqr...           0.835985
# 16  {'criterion': 'log_loss', 'max_features': 'log...           0.872432
# 17  {'criterion': 'log_loss', 'max_features': 'log...           0.782971
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.821429           0.804584           0.893717
# 1            0.804584           0.841398           0.766661
# 2            0.840114           0.769053           0.841045
# 3            0.821429           0.841398           0.841653
# 4            0.858503           0.770909           0.822861
# 5            0.875644           0.842217           0.800053
# 6            0.840114           0.807155           0.893717
# 7            0.821429           0.824293           0.929144
# 8            0.857143           0.789152           0.891667
# 9            0.838326           0.821429           0.875548
# 10           0.855314           0.769053           0.859025
# 11           0.819142           0.754011           0.839990
# 12           0.840114           0.807155           0.893717
# 13           0.782971           0.821429           0.911105
# 14           0.821429           0.807155           0.892857
# 15           0.857143           0.858503           0.821429
# 16           0.802399           0.840114           0.892857
# 17           0.770909           0.823129           0.858289
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.910254         0.845180        0.047391                6
# 1            0.891667         0.824103        0.041490               15
# 2            0.874356         0.824097        0.037131               16
# 3            0.819444         0.823073        0.018426               17
# 4            0.855556         0.825394        0.031686               13
# 5            0.853485         0.841477        0.024732                9
# 6            0.910254         0.854076        0.040852                1
# 7            0.819444         0.853349        0.042712                3
# 8            0.853485         0.849352        0.033250                4
# 9            0.838458         0.846181        0.018529                5
# 10           0.853485         0.838804        0.034924               11
# 11           0.800053         0.824415        0.050902               14
# 12           0.910254         0.854076        0.040852                1
# 13           0.776316         0.833215        0.052253               12
# 14           0.833784         0.842108        0.029895                8
# 15           0.833784         0.841369        0.014329               10
# 16           0.813596         0.844280        0.034250                7
# 17           0.819444         0.810948        0.031137               18

# %%
print("Best Params {}",format(grid.best_params_))
# Out:
# Best Params {} {'criterion': 'entropy', 'max_features': None, 'splitter': 'best'}

# %%
from sklearn.metrics import f1_score
f1_macro = f1_score( y_test , grid_predictions, average='weighted')
print(f1_macro)
# Out:
# 0.9010268800966474

# %%
Future_Predictions = grid.predict([[32,150000,1]])
Future_Predictions
# Out:
# C:\Users\Poorni Gnaneswaran\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])
