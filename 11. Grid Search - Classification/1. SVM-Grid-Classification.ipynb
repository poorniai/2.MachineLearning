# %%
import numpy as np
import matplotlib as plt
import pandas as pd

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")
dataset=dataset.drop("User ID", axis=1)
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
    independent = dataset[['Age', 'EstimatedSalary', 'Gender_Male']]
    dependent = dataset[['Purchased']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

param_grid= {
   #   'kernel':['linear','rbf','poly','skmoid'],
    'kernel':['rbf'],
   # 'gamma': ['auto','scale'],
    #    'C':[10,100,1000,2000,3000]
    'C':[3000]
}

grid=GridSearchCV(SVC(probability=True),param_grid,refit=True,verbose=3,n_jobs=-1,cv=5,scoring='f1_weighted')
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\Poorni Gnaneswaran\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(cv=5, estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [3000], 'kernel': ['rbf']}, scoring='f1_weighted',
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions=grid.predict(X_test)

from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,grid_predictions)

from sklearn.metrics import classification_report
clf_report = classification_report(y_test,grid_predictions)

from sklearn.metrics import f1_score
f1_macro = f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:",format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {}: {'C': 3000, 'kernel': 'rbf'} 0.7789778905400506

# %%
print(cm)
# Out:
# [[77  2]
#  [22 19]]

# %%
print (clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.97      0.87        79
#            1       0.90      0.46      0.61        41
#
#     accuracy                           0.80       120
#    macro avg       0.84      0.72      0.74       120
# weighted avg       0.82      0.80      0.78       120

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.083965      0.027185         0.012928        0.008795     3000
#
#   param_kernel                        params  split0_test_score  \
# 0          rbf  {'C': 3000, 'kernel': 'rbf'}           0.795918
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0            0.78597           0.699092           0.796847           0.718293
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.759224        0.041877                1

# %%
Future_Prediction = grid.predict([[19,19000,1]])
print("Future_Prediction={}",format(Future_Prediction))
# Out:
# Future_Prediction={} [0]
# C:\Users\Poorni Gnaneswaran\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
Future_Prediction = grid.predict([[32,150000,1]])
print("Future_Prediction={}",format(Future_Prediction))
# Out:
# Future_Prediction={} [1]
# C:\Users\Poorni Gnaneswaran\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
