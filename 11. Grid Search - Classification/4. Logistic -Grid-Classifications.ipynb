# %%
import numpy as np
import matplotlib as plt
import pandas as pd

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")
dataset.drop("User ID", axis=1)
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset['Purchased'].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
independent = dataset[['Age', 'EstimatedSalary', 'Gender_Male']]
dependent = dataset[['Purchased']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

from sklearn.model_selection import GridSearchCV 
from sklearn.linear_model import LogisticRegression
param_grid = {
    'C': [0.01, 0.1, 1, 10, 100],
    'penalty': ['l1', 'l2'],
    'solver': ['liblinear'],
    'max_iter': [100, 500, 1000]
}

grid=GridSearchCV(LogisticRegression(),param_grid,refit=True,n_jobs=-1, cv=5, scoring='f1_weighted')
grid.fit(X_train,y_train)
# Out:
# C:\Users\Poorni Gnaneswaran\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(cv=5, estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': [0.01, 0.1, 1, 10, 100],
#                          'max_iter': [100, 500, 1000], 'penalty': ['l1', 'l2'],
#                          'solver': ['liblinear']},
#              scoring='f1_weighted')

# %%
re=grid.cv_results_
grid_predictions=grid.predict(X_test)

from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,grid_predictions)

from sklearn.metrics import classification_report
clf_report=classification_report(y_test,grid_predictions)

# %%
table = pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.018780      0.004415         0.024829        0.004011     0.01
# 1        0.016726      0.005915         0.025862        0.002023     0.01
# 2        0.009616      0.002345         0.025765        0.001580     0.01
# 3        0.011484      0.001250         0.027184        0.001314     0.01
# 4        0.010606      0.002198         0.026127        0.001655     0.01
# 5        0.011890      0.000963         0.029389        0.003148     0.01
# 6        0.015039      0.002377         0.026303        0.001870     0.10
# 7        0.012128      0.001258         0.027412        0.003786     0.10
# 8        0.012485      0.000394         0.027674        0.000934     0.10
# 9        0.012129      0.002240         0.028492        0.003380     0.10
# 10       0.012528      0.002239         0.025674        0.002195     0.10
# 11       0.010411      0.001350         0.025688        0.001577     0.10
# 12       0.012685      0.001806         0.023631        0.003046     1.00
# 13       0.012379      0.001092         0.024977        0.000998     1.00
# 14       0.012619      0.001652         0.024625        0.001605     1.00
# 15       0.012970      0.002676         0.025757        0.001756     1.00
# 16       0.012456      0.001171         0.023105        0.003614     1.00
# 17       0.012708      0.000664         0.024499        0.001975     1.00
# 18       0.012210      0.000799         0.023504        0.002441    10.00
# 19       0.010862      0.000489         0.023876        0.001343    10.00
# 20       0.013178      0.001184         0.024509        0.001269    10.00
# 21       0.011597      0.001615         0.024912        0.000902    10.00
# 22       0.012502      0.001615         0.024900        0.001820    10.00
# 23       0.011163      0.000640         0.023690        0.001625    10.00
# 24       0.014415      0.002907         0.024250        0.002392   100.00
# 25       0.011748      0.001054         0.024593        0.000791   100.00
# 26       0.013929      0.000641         0.024800        0.004139   100.00
# 27       0.011448      0.001439         0.022899        0.003623   100.00
# 28       0.013072      0.002731         0.023780        0.005154   100.00
# 29       0.010945      0.002091         0.019547        0.002628   100.00
#
#     param_max_iter param_penalty param_solver  \
# 0              100            l1    liblinear
# 1              100            l2    liblinear
# 2              500            l1    liblinear
# 3              500            l2    liblinear
# 4             1000            l1    liblinear
# 5             1000            l2    liblinear
# 6              100            l1    liblinear
# 7              100            l2    liblinear
# 8              500            l1    liblinear
# 9              500            l2    liblinear
# 10            1000            l1    liblinear
# 11            1000            l2    liblinear
# 12             100            l1    liblinear
# 13             100            l2    liblinear
# 14             500            l1    liblinear
# 15             500            l2    liblinear
# 16            1000            l1    liblinear
# 17            1000            l2    liblinear
# 18             100            l1    liblinear
# 19             100            l2    liblinear
# 20             500            l1    liblinear
# 21             500            l2    liblinear
# 22            1000            l1    liblinear
# 23            1000            l2    liblinear
# 24             100            l1    liblinear
# 25             100            l2    liblinear
# 26             500            l1    liblinear
# 27             500            l2    liblinear
# 28            1000            l1    liblinear
# 29            1000            l2    liblinear
#
#                                                params  split0_test_score  \
# 0   {'C': 0.01, 'max_iter': 100, 'penalty': 'l1', ...           0.503106
# 1   {'C': 0.01, 'max_iter': 100, 'penalty': 'l2', ...           0.503106
# 2   {'C': 0.01, 'max_iter': 500, 'penalty': 'l1', ...           0.503106
# 3   {'C': 0.01, 'max_iter': 500, 'penalty': 'l2', ...           0.503106
# 4   {'C': 0.01, 'max_iter': 1000, 'penalty': 'l1',...           0.503106
# 5   {'C': 0.01, 'max_iter': 1000, 'penalty': 'l2',...           0.503106
# 6   {'C': 0.1, 'max_iter': 100, 'penalty': 'l1', '...           0.763066
# 7   {'C': 0.1, 'max_iter': 100, 'penalty': 'l2', '...           0.503106
# 8   {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', '...           0.763066
# 9   {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', '...           0.503106
# 10  {'C': 0.1, 'max_iter': 1000, 'penalty': 'l1', ...           0.763066
# 11  {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2', ...           0.503106
# 12  {'C': 1, 'max_iter': 100, 'penalty': 'l1', 'so...           0.835985
# 13  {'C': 1, 'max_iter': 100, 'penalty': 'l2', 'so...           0.503106
# 14  {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'so...           0.835985
# 15  {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'so...           0.503106
# 16  {'C': 1, 'max_iter': 1000, 'penalty': 'l1', 's...           0.835985
# 17  {'C': 1, 'max_iter': 1000, 'penalty': 'l2', 's...           0.503106
# 18  {'C': 10, 'max_iter': 100, 'penalty': 'l1', 's...           0.835985
# 19  {'C': 10, 'max_iter': 100, 'penalty': 'l2', 's...           0.503106
# 20  {'C': 10, 'max_iter': 500, 'penalty': 'l1', 's...           0.835985
# 21  {'C': 10, 'max_iter': 500, 'penalty': 'l2', 's...           0.503106
# 22  {'C': 10, 'max_iter': 1000, 'penalty': 'l1', '...           0.835985
# 23  {'C': 10, 'max_iter': 1000, 'penalty': 'l2', '...           0.503106
# 24  {'C': 100, 'max_iter': 100, 'penalty': 'l1', '...           0.835985
# 25  {'C': 100, 'max_iter': 100, 'penalty': 'l2', '...           0.503106
# 26  {'C': 100, 'max_iter': 500, 'penalty': 'l1', '...           0.835985
# 27  {'C': 100, 'max_iter': 500, 'penalty': 'l2', '...           0.503106
# 28  {'C': 100, 'max_iter': 1000, 'penalty': 'l1', ...           0.835985
# 29  {'C': 100, 'max_iter': 1000, 'penalty': 'l2', ...           0.503106
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.503106           0.503106           0.480769
# 1            0.503106           0.542648           0.480769
# 2            0.503106           0.503106           0.480769
# 3            0.503106           0.542648           0.480769
# 4            0.503106           0.503106           0.480769
# 5            0.503106           0.542648           0.480769
# 6            0.737557           0.644599           0.890114
# 7            0.503106           0.591398           0.480769
# 8            0.737557           0.644599           0.890114
# 9            0.503106           0.591398           0.480769
# 10           0.737557           0.658971           0.890114
# 11           0.503106           0.591398           0.480769
# 12           0.802399           0.644599           0.927778
# 13           0.503106           0.591398           0.480769
# 14           0.802399           0.644599           0.927778
# 15           0.503106           0.591398           0.480769
# 16           0.802399           0.644599           0.927778
# 17           0.503106           0.591398           0.480769
# 18           0.802399           0.644599           0.927778
# 19           0.503106           0.591398           0.480769
# 20           0.802399           0.644599           0.927778
# 21           0.503106           0.591398           0.480769
# 22           0.802399           0.644599           0.927778
# 23           0.503106           0.591398           0.480769
# 24           0.802399           0.644599           0.927778
# 25           0.503106           0.721707           0.480769
# 26           0.802399           0.644599           0.927778
# 27           0.503106           0.721707           0.480769
# 28           0.802399           0.644599           0.927778
# 29           0.503106           0.721707           0.480769
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.480769         0.494171        0.010943               28
# 1            0.520202         0.509966        0.020589               25
# 2            0.480769         0.494171        0.010943               28
# 3            0.520202         0.509966        0.020589               25
# 4            0.480769         0.494171        0.010943               28
# 5            0.520202         0.509966        0.020589               25
# 6            0.847662         0.776600        0.086101               11
# 7            0.520202         0.519716        0.037966               16
# 8            0.847662         0.776600        0.086101               11
# 9            0.520202         0.519716        0.037966               16
# 10           0.847662         0.779474        0.081778               10
# 11           0.520202         0.519716        0.037966               16
# 12           0.926743         0.827501        0.103980                1
# 13           0.520202         0.519716        0.037966               16
# 14           0.926743         0.827501        0.103980                1
# 15           0.520202         0.519716        0.037966               16
# 16           0.926743         0.827501        0.103980                1
# 17           0.520202         0.519716        0.037966               16
# 18           0.909115         0.823975        0.100806                4
# 19           0.520202         0.519716        0.037966               16
# 20           0.890114         0.820175        0.097839                6
# 21           0.520202         0.519716        0.037966               16
# 22           0.890114         0.820175        0.097839                6
# 23           0.520202         0.519716        0.037966               16
# 24           0.890114         0.820175        0.097839                6
# 25           0.520202         0.545778        0.088852               13
# 26           0.890114         0.820175        0.097839                6
# 27           0.520202         0.545778        0.088852               13
# 28           0.907658         0.823684        0.100561                5
# 29           0.520202         0.545778        0.088852               13

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average="weighted")

print("Best model {}",format(grid.best_params_), f1_macro)
# Out:
# Best model {} {'C': 1, 'max_iter': 100, 'penalty': 'l1', 'solver': 'liblinear'} 0.8638425331621737

# %%
Future_Predictions = grid.predict([[32,150000,1]])
Future_Predictions
# Out:
# C:\Users\Poorni Gnaneswaran\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])
