# %%
import numpy as np
import matplotlib as plt
import pandas as pd

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")
dataset.drop("Purchased", axis=1)
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
independent = dataset[['Age', 'EstimatedSalary', 'Gender_Male']]
dependent = dataset[['Purchased']]

# %%
dataset['Purchased'].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30, random_state=0)

from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

param_grid = {
    'n_estimators': [50, 100, 200],
    'criterion': ['gini', 'entropy', 'log_loss'],
  #  'max_depth': [None, 5, 10, 20],
 #   'max_features': ['sqrt', 'log2', None],
    'bootstrap': [True, False]
}

grid = GridSearchCV(RandomForestClassifier(),param_grid,refit=True,verbose=3,n_jobs=-1,cv=5,scoring='f1_weighted')

grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# C:\Users\Poorni Gnaneswaran\anaconda3\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [50, 100, 200]},
#              scoring='f1_weighted', verbose=3)

# %%
re=grid.cv_results_
grid_predictions=grid.predict(X_test)

from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,grid_predictions)

from sklearn.metrics import classification_report
clf_report=classification_report(y_test,grid_predictions)

from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')

# %%
print("Best model{}:",format(grid.best_params_),f1_macro)
# Out:
# Best model{}: {'bootstrap': True, 'criterion': 'entropy', 'max_features': 'sqrt', 'n_estimators': 200} 0.9085936101092268

# %%
table = pd.DataFrame.from_dict(re)
print(table)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.259888      0.008921         0.036977        0.000825
# 1        0.530020      0.016243         0.044916        0.004117
# 2        1.102234      0.009225         0.066235        0.002930
# 3        0.282713      0.002580         0.036582        0.004010
# 4        0.558047      0.006763         0.043871        0.002476
# 5        1.103393      0.011930         0.065308        0.003041
# 6        0.291211      0.007387         0.036103        0.000775
# 7        0.555669      0.018208         0.043618        0.002033
# 8        1.108063      0.038012         0.064586        0.003140
# 9        0.266211      0.003390         0.034347        0.002109
# 10       0.554542      0.008254         0.044357        0.001809
# 11       1.099836      0.018335         0.063443        0.001438
# 12       0.285182      0.005135         0.033775        0.002686
# 13       0.548926      0.005526         0.044087        0.001745
# 14       1.092929      0.013734         0.061546        0.003398
# 15       0.288432      0.004812         0.036038        0.002128
# 16       0.578574      0.007301         0.044945        0.000643
# 17       1.146782      0.021239         0.062744        0.002235
# 18       0.286794      0.006680         0.034580        0.001396
# 19       0.560961      0.009773         0.043413        0.002848
# 20       1.106160      0.011986         0.064250        0.001989
# 21       0.282973      0.004774         0.033988        0.001219
# 22       0.564785      0.008772         0.044186        0.000701
# 23       1.104462      0.010466         0.065638        0.004440
# 24       0.292811      0.004246         0.033252        0.001516
# 25       0.611650      0.015022         0.048100        0.008494
# 26       1.199689      0.052834         0.062569        0.003070
# 27       0.258751      0.015464         0.033457        0.010754
# 28       0.395444      0.004991         0.040274        0.005641
# 29       0.798902      0.034463         0.061550        0.002447
# 30       0.210287      0.007114         0.033562        0.001619
# 31       0.405028      0.017261         0.041493        0.005163
# 32       0.877865      0.105591         0.060723        0.016179
# 33       0.265823      0.048352         0.036277        0.002893
# 34       0.512659      0.072793         0.045451        0.008020
# 35       0.904187      0.090054         0.060920        0.011225
# 36       0.252345      0.005185         0.039849        0.005050
# 37       0.493583      0.045477         0.046116        0.008869
# 38       0.876366      0.084458         0.061952        0.003190
# 39       0.254526      0.014068         0.037859        0.005281
# 40       0.417374      0.015926         0.041922        0.003080
# 41       0.814955      0.007097         0.066715        0.003244
# 42       0.223056      0.006667         0.032301        0.001365
# 43       0.444654      0.025975         0.043795        0.000923
# 44       0.908124      0.008911         0.066644        0.002628
# 45       0.223464      0.002807         0.033115        0.003104
# 46       0.425484      0.012542         0.045413        0.002769
# 47       0.867334      0.016227         0.064751        0.003967
# 48       0.225967      0.019432         0.035163        0.008078
# 49       0.425536      0.028462         0.045952        0.001159
# 50       0.837416      0.035544         0.061182        0.001896
# 51       0.234722      0.008781         0.033139        0.003302
# 52       0.476769      0.008669         0.044550        0.000826
# 53       0.825100      0.033002         0.050505        0.005909
#
#     param_bootstrap param_criterion param_max_features  param_n_estimators  \
# 0              True            gini               sqrt                  50
# 1              True            gini               sqrt                 100
# 2              True            gini               sqrt                 200
# 3              True            gini               log2                  50
# 4              True            gini               log2                 100
# 5              True            gini               log2                 200
# 6              True            gini               None                  50
# 7              True            gini               None                 100
# 8              True            gini               None                 200
# 9              True         entropy               sqrt                  50
# 10             True         entropy               sqrt                 100
# 11             True         entropy               sqrt                 200
# 12             True         entropy               log2                  50
# 13             True         entropy               log2                 100
# 14             True         entropy               log2                 200
# 15             True         entropy               None                  50
# 16             True         entropy               None                 100
# 17             True         entropy               None                 200
# 18             True        log_loss               sqrt                  50
# 19             True        log_loss               sqrt                 100
# 20             True        log_loss               sqrt                 200
# 21             True        log_loss               log2                  50
# 22             True        log_loss               log2                 100
# 23             True        log_loss               log2                 200
# 24             True        log_loss               None                  50
# 25             True        log_loss               None                 100
# 26             True        log_loss               None                 200
# 27            False            gini               sqrt                  50
# 28            False            gini               sqrt                 100
# 29            False            gini               sqrt                 200
# 30            False            gini               log2                  50
# 31            False            gini               log2                 100
# 32            False            gini               log2                 200
# 33            False            gini               None                  50
# 34            False            gini               None                 100
# 35            False            gini               None                 200
# 36            False         entropy               sqrt                  50
# 37            False         entropy               sqrt                 100
# 38            False         entropy               sqrt                 200
# 39            False         entropy               log2                  50
# 40            False         entropy               log2                 100
# 41            False         entropy               log2                 200
# 42            False         entropy               None                  50
# 43            False         entropy               None                 100
# 44            False         entropy               None                 200
# 45            False        log_loss               sqrt                  50
# 46            False        log_loss               sqrt                 100
# 47            False        log_loss               sqrt                 200
# 48            False        log_loss               log2                  50
# 49            False        log_loss               log2                 100
# 50            False        log_loss               log2                 200
# 51            False        log_loss               None                  50
# 52            False        log_loss               None                 100
# 53            False        log_loss               None                 200
#
#                                                params  split0_test_score  \
# 0   {'bootstrap': True, 'criterion': 'gini', 'max_...           0.874254
# 1   {'bootstrap': True, 'criterion': 'gini', 'max_...           0.874254
# 2   {'bootstrap': True, 'criterion': 'gini', 'max_...           0.874254
# 3   {'bootstrap': True, 'criterion': 'gini', 'max_...           0.892857
# 4   {'bootstrap': True, 'criterion': 'gini', 'max_...           0.874254
# 5   {'bootstrap': True, 'criterion': 'gini', 'max_...           0.874254
# 6   {'bootstrap': True, 'criterion': 'gini', 'max_...           0.835985
# 7   {'bootstrap': True, 'criterion': 'gini', 'max_...           0.855314
# 8   {'bootstrap': True, 'criterion': 'gini', 'max_...           0.855314
# 9   {'bootstrap': True, 'criterion': 'entropy', 'm...           0.874254
# 10  {'bootstrap': True, 'criterion': 'entropy', 'm...           0.874254
# 11  {'bootstrap': True, 'criterion': 'entropy', 'm...           0.892857
# 12  {'bootstrap': True, 'criterion': 'entropy', 'm...           0.892857
# 13  {'bootstrap': True, 'criterion': 'entropy', 'm...           0.874254
# 14  {'bootstrap': True, 'criterion': 'entropy', 'm...           0.874254
# 15  {'bootstrap': True, 'criterion': 'entropy', 'm...           0.835985
# 16  {'bootstrap': True, 'criterion': 'entropy', 'm...           0.855314
# 17  {'bootstrap': True, 'criterion': 'entropy', 'm...           0.855314
# 18  {'bootstrap': True, 'criterion': 'log_loss', '...           0.892857
# 19  {'bootstrap': True, 'criterion': 'log_loss', '...           0.874254
# 20  {'bootstrap': True, 'criterion': 'log_loss', '...           0.874254
# 21  {'bootstrap': True, 'criterion': 'log_loss', '...           0.874254
# 22  {'bootstrap': True, 'criterion': 'log_loss', '...           0.874254
# 23  {'bootstrap': True, 'criterion': 'log_loss', '...           0.874254
# 24  {'bootstrap': True, 'criterion': 'log_loss', '...           0.835985
# 25  {'bootstrap': True, 'criterion': 'log_loss', '...           0.855314
# 26  {'bootstrap': True, 'criterion': 'log_loss', '...           0.874254
# 27  {'bootstrap': False, 'criterion': 'gini', 'max...           0.874254
# 28  {'bootstrap': False, 'criterion': 'gini', 'max...           0.874254
# 29  {'bootstrap': False, 'criterion': 'gini', 'max...           0.892857
# 30  {'bootstrap': False, 'criterion': 'gini', 'max...           0.874254
# 31  {'bootstrap': False, 'criterion': 'gini', 'max...           0.874254
# 32  {'bootstrap': False, 'criterion': 'gini', 'max...           0.874254
# 33  {'bootstrap': False, 'criterion': 'gini', 'max...           0.799537
# 34  {'bootstrap': False, 'criterion': 'gini', 'max...           0.799537
# 35  {'bootstrap': False, 'criterion': 'gini', 'max...           0.799537
# 36  {'bootstrap': False, 'criterion': 'entropy', '...           0.874254
# 37  {'bootstrap': False, 'criterion': 'entropy', '...           0.874254
# 38  {'bootstrap': False, 'criterion': 'entropy', '...           0.874254
# 39  {'bootstrap': False, 'criterion': 'entropy', '...           0.874254
# 40  {'bootstrap': False, 'criterion': 'entropy', '...           0.874254
# 41  {'bootstrap': False, 'criterion': 'entropy', '...           0.874254
# 42  {'bootstrap': False, 'criterion': 'entropy', '...           0.819142
# 43  {'bootstrap': False, 'criterion': 'entropy', '...           0.819142
# 44  {'bootstrap': False, 'criterion': 'entropy', '...           0.819142
# 45  {'bootstrap': False, 'criterion': 'log_loss', ...           0.874254
# 46  {'bootstrap': False, 'criterion': 'log_loss', ...           0.874254
# 47  {'bootstrap': False, 'criterion': 'log_loss', ...           0.874254
# 48  {'bootstrap': False, 'criterion': 'log_loss', ...           0.892857
# 49  {'bootstrap': False, 'criterion': 'log_loss', ...           0.874254
# 50  {'bootstrap': False, 'criterion': 'log_loss', ...           0.874254
# 51  {'bootstrap': False, 'criterion': 'log_loss', ...           0.819142
# 52  {'bootstrap': False, 'criterion': 'log_loss', ...           0.819142
# 53  {'bootstrap': False, 'criterion': 'log_loss', ...           0.819142
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.857143           0.823129           0.893717
# 1            0.875644           0.841398           0.911105
# 2            0.858503           0.841398           0.929144
# 3            0.875644           0.824293           0.929144
# 4            0.857143           0.841398           0.929144
# 5            0.857143           0.841398           0.911105
# 6            0.858503           0.824293           0.875548
# 7            0.840114           0.824293           0.875548
# 8            0.858503           0.841398           0.875548
# 9            0.840114           0.841398           0.911105
# 10           0.875644           0.823129           0.911105
# 11           0.875644           0.823129           0.911105
# 12           0.875644           0.823129           0.911105
# 13           0.840114           0.823129           0.911105
# 14           0.857143           0.841398           0.911105
# 15           0.875644           0.824293           0.875548
# 16           0.857143           0.841398           0.893717
# 17           0.840114           0.824293           0.875548
# 18           0.840114           0.841398           0.911105
# 19           0.875644           0.823129           0.929144
# 20           0.875644           0.841398           0.911105
# 21           0.857143           0.841398           0.911105
# 22           0.857143           0.841398           0.911105
# 23           0.875644           0.823129           0.911105
# 24           0.838326           0.841398           0.911692
# 25           0.857143           0.841398           0.893717
# 26           0.858503           0.824293           0.875548
# 27           0.838326           0.806153           0.859025
# 28           0.857143           0.806153           0.859025
# 29           0.857143           0.806153           0.859025
# 30           0.838326           0.824293           0.859025
# 31           0.857143           0.824293           0.859025
# 32           0.857143           0.806153           0.859025
# 33           0.821429           0.804584           0.875548
# 34           0.821429           0.804584           0.893717
# 35           0.821429           0.804584           0.893717
# 36           0.875644           0.824293           0.893717
# 37           0.857143           0.824293           0.893717
# 38           0.840114           0.806153           0.859025
