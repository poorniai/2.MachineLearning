# %%
import Helper
import pickle

# %%
filename="Model_SVR.sav"
independent,dependent = Helper.preprocess_dummies()

# %%
X_train,X_test,y_train,y_test=Helper.split_train_test(independent,dependent)

# %%
X_train,X_test,sc = Helper.preprocess_scaler(X_train,X_test)

# %%
y_train,y_test,scy = Helper.preprocess_scaler(y_train,y_test)

# %%
preinput=sc.transform([[1300,12000,4000,0,1]])
# Out:
# C:\Users\Poorni Gnaneswaran\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
loaded_model=pickle.load(open(filename,'rb'))
result=loaded_model.predict(preinput)

# %%
result
# Out:
# array([108604.26552372])

# %%
preoutput = scy.inverse_transform([result])
preoutput
# Out:
# array([[4.67147963e+09]])
